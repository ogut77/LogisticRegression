# %% [markdown]
# <a href="https://colab.research.google.com/github/ogut77/LogisticRegression/blob/master/LightGBM_Undersampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score
# Grafik çizdirmek için gerekli paket.
import matplotlib.pyplot as plt
# LightGBM paketi.
import lightgbm as lgb
import numpy as np
#Uyarı mesajlarını kapatmak için
import warnings
warnings.filterwarnings("ignore")
# Veri çerçevelerini daha güzel görselleştirmek için
from IPython.display import display, HTML
# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d2 = pd.read_csv('/content/drive/My Drive/Santander/train.csv')
d2.drop(['Unnamed: 0'], axis = 1, inplace = True)
d2.drop(['ID_code'], axis = 1, inplace = True)
d2.head(2)
# Out:
#    target    var_0   var_1    var_2  var_3    var_4   var_5   var_6    var_7  \
# 0       0   8.9255 -6.7863  11.9081  5.093  11.4607 -9.2834  5.1187  18.6266
# 1       0  11.5006 -4.1473  13.8588  5.389  12.3622  7.0433  5.6208  16.5338
#
#     var_8   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0 -4.9200   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  3.1468   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
#
# [2 rows x 201 columns]

# %%
from sklearn.model_selection import train_test_split

df, te = train_test_split(d2, test_size=0.2)
df.shape
# Out:
# (160000, 201)

# %%
no_frauds = len(df[df['target'] == 1])
non_fraud_indices = df[df.target == 0].index
import numpy as np
random_indices = np.random.choice(non_fraud_indices,no_frauds, replace=False)
fraud_indices = df[df.target == 1].index
under_sample_indices = np.concatenate([fraud_indices,random_indices])
under_sample = df.loc[under_sample_indices]
df=under_sample.copy()

# %%
X_train=df.iloc[:,1:]
X_test=te.iloc[:,1:]
y_train=df.iloc[:,0:1]
y_test=te.iloc[:,0:1]

# %%
print(d2.isnull().sum())

# %%
lgb_train = lgb.Dataset(data=X_train, label=y_train,  free_raw_data=False)

# %%
parameters = {
    'application': 'binary',
    'objective': 'binary',
    'metric': 'auc',
    'is_unbalance': 'true',
    'boosting': 'rf',
    'num_leaves': 31,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}

# %%
gbm = lgb.train(parameters ,lgb_train)

# %%
y_pred = gbm.predict(X_test)

print('Eğri altı alan değeri:', roc_auc_score(y_test, y_pred))
print('İsabetlilik değeri:', accuracy_score(y_test, ( y_pred>= 0.5)*1))
# Out:
# Eğri altı alan değeri: 0.7726133550297062
# İsabetlilik değeri: 0.123425

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'verbose': -1
}

# %%
gbm = lgb.train(params ,lgb_train)

# %%
y_pred = gbm.predict(X_test)

print('Eğri altı alan değeri:', roc_auc_score(y_test, y_pred))
print('İsabetlilik değeri:', accuracy_score(y_test, ( y_pred>= 0.5)*1))
# Out:
# Eğri altı alan değeri: 0.8434023493033269
# İsabetlilik değeri: 0.747325

# %%
# Değerlendirme veri kümesini oluşturuyoruz.
lgb_eval = lgb.Dataset(data=X_test, label=y_test, reference=lgb_train,  free_raw_data=False)

# Eğitim parametrelerini belirleyelim
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'verbose': -1
}

print('Eğitim...')
# Modeli eğitelim
# Bu sefer değerlendirme veri kümesini de tanıtıyoruz.
evals_result={}
gbm = lgb.train(params,
                lgb_train,
                valid_sets = lgb_eval,
                num_boost_round= 5000,
                early_stopping_rounds= 100,
                evals_result=evals_result)
print('Eğitim bitti...')

# Tahmin ve değerlendirme
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

print('En iyi sonucu veren iterasyon: ', gbm.best_iteration)
print('Eğri altı alan değeri:', roc_auc_score(y_test, y_pred))
print('İsabetlilik değeri:', accuracy_score(y_test, ( y_pred>= 0.5)*1))
# Out:
# Eğitim...
# [1]	valid_0's auc: 0.65633
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's auc: 0.681163
# [3]	valid_0's auc: 0.682112
# [4]	valid_0's auc: 0.688665
# [5]	valid_0's auc: 0.695622
# [6]	valid_0's auc: 0.70185
# [7]	valid_0's auc: 0.708581
# [8]	valid_0's auc: 0.71421
# [9]	valid_0's auc: 0.7189
# [10]	valid_0's auc: 0.722901
# [11]	valid_0's auc: 0.728278
# [12]	valid_0's auc: 0.73335
# [13]	valid_0's auc: 0.736215
# [14]	valid_0's auc: 0.740867
# [15]	valid_0's auc: 0.744085
# [16]	valid_0's auc: 0.747929
# [17]	valid_0's auc: 0.751919
# [18]	valid_0's auc: 0.755758
# [19]	valid_0's auc: 0.7595
# [20]	valid_0's auc: 0.762312
# [21]	valid_0's auc: 0.765892
# [22]	valid_0's auc: 0.766939
# [23]	valid_0's auc: 0.769523
# [24]	valid_0's auc: 0.772078
# [25]	valid_0's auc: 0.774662
# [26]	valid_0's auc: 0.777368
# [27]	valid_0's auc: 0.779405
# [28]	valid_0's auc: 0.780703
# [29]	valid_0's auc: 0.78231
# [30]	valid_0's auc: 0.785075
# [31]	valid_0's auc: 0.787331
# [32]	valid_0's auc: 0.788986
# [33]	valid_0's auc: 0.790835
# [34]	valid_0's auc: 0.792561
# [35]	valid_0's auc: 0.79433
# [36]	valid_0's auc: 0.796026
# [37]	valid_0's auc: 0.798532
# [38]	valid_0's auc: 0.799144
# [39]	valid_0's auc: 0.800769
# [40]	valid_0's auc: 0.801811
# [41]	valid_0's auc: 0.802729
# [42]	valid_0's auc: 0.803953
# [43]	valid_0's auc: 0.805066
# [44]	valid_0's auc: 0.805908
# [45]	valid_0's auc: 0.807016
# [46]	valid_0's auc: 0.807592
# [47]	valid_0's auc: 0.808783
# [48]	valid_0's auc: 0.809703
# [49]	valid_0's auc: 0.810936
# [50]	valid_0's auc: 0.811586
# [51]	valid_0's auc: 0.812621
# [52]	valid_0's auc: 0.813754
# [53]	valid_0's auc: 0.814695
# [54]	valid_0's auc: 0.815026
# [55]	valid_0's auc: 0.81597
# [56]	valid_0's auc: 0.816784
# [57]	valid_0's auc: 0.817932
# [58]	valid_0's auc: 0.819029
# [59]	valid_0's auc: 0.819831
# [60]	valid_0's auc: 0.820549
# [61]	valid_0's auc: 0.821653
# [62]	valid_0's auc: 0.822629
# [63]	valid_0's auc: 0.823664
# [64]	valid_0's auc: 0.824041
# [65]	valid_0's auc: 0.824807
# [66]	valid_0's auc: 0.825831
# [67]	valid_0's auc: 0.82672
# [68]	valid_0's auc: 0.827399
# [69]	valid_0's auc: 0.828415
# [70]	valid_0's auc: 0.828823
# [71]	valid_0's auc: 0.829084
# [72]	valid_0's auc: 0.829561
# [73]	valid_0's auc: 0.83017
# [74]	valid_0's auc: 0.83105
# [75]	valid_0's auc: 0.831424
# [76]	valid_0's auc: 0.832023
# [77]	valid_0's auc: 0.832221
# [78]	valid_0's auc: 0.83277
# [79]	valid_0's auc: 0.833147
# [80]	valid_0's auc: 0.833639
# [81]	valid_0's auc: 0.834366
# [82]	valid_0's auc: 0.835107
# [83]	valid_0's auc: 0.83563
# [84]	valid_0's auc: 0.836248
# [85]	valid_0's auc: 0.836715
# [86]	valid_0's auc: 0.837227
# [87]	valid_0's auc: 0.837808
# [88]	valid_0's auc: 0.838259
# [89]	valid_0's auc: 0.838551
# [90]	valid_0's auc: 0.839014
# [91]	valid_0's auc: 0.839318
# [92]	valid_0's auc: 0.839633
# [93]	valid_0's auc: 0.840206
# [94]	valid_0's auc: 0.840595
# [95]	valid_0's auc: 0.841238
# [96]	valid_0's auc: 0.841639
# [97]	valid_0's auc: 0.842045
# [98]	valid_0's auc: 0.842428
# [99]	valid_0's auc: 0.84296
# [100]	valid_0's auc: 0.843402
# [101]	valid_0's auc: 0.843797
# [102]	valid_0's auc: 0.844199
# [103]	valid_0's auc: 0.84445
# [104]	valid_0's auc: 0.845016
# [105]	valid_0's auc: 0.845218
# [106]	valid_0's auc: 0.845509
# [107]	valid_0's auc: 0.84588
# [108]	valid_0's auc: 0.846286
# [109]	valid_0's auc: 0.846827
# [110]	valid_0's auc: 0.846921
# [111]	valid_0's auc: 0.847175
# [112]	valid_0's auc: 0.847458
# [113]	valid_0's auc: 0.847751
# [114]	valid_0's auc: 0.848221
# [115]	valid_0's auc: 0.848668
# [116]	valid_0's auc: 0.848905
# [117]	valid_0's auc: 0.849322
# [118]	valid_0's auc: 0.849566
# [119]	valid_0's auc: 0.849863
# [120]	valid_0's auc: 0.850088
# [121]	valid_0's auc: 0.85044
# [122]	valid_0's auc: 0.850828
# [123]	valid_0's auc: 0.851306
# [124]	valid_0's auc: 0.851572
# [125]	valid_0's auc: 0.851941
# [126]	valid_0's auc: 0.852062
# [127]	valid_0's auc: 0.852295
# [128]	valid_0's auc: 0.852463
# [129]	valid_0's auc: 0.852739
# [130]	valid_0's auc: 0.853169
# [131]	valid_0's auc: 0.853375
# [132]	valid_0's auc: 0.853684
# [133]	valid_0's auc: 0.853891
# [134]	valid_0's auc: 0.854099
# [135]	valid_0's auc: 0.854342
# [136]	valid_0's auc: 0.854635
# [137]	valid_0's auc: 0.854947
# [138]	valid_0's auc: 0.855203
# [139]	valid_0's auc: 0.855404
# [140]	valid_0's auc: 0.855634
# [141]	valid_0's auc: 0.856109
# [142]	valid_0's auc: 0.856263
# [143]	valid_0's auc: 0.856453
# [144]	valid_0's auc: 0.856613
# [145]	valid_0's auc: 0.85669
# [146]	valid_0's auc: 0.856977
# [147]	valid_0's auc: 0.857314
# [148]	valid_0's auc: 0.857436
# [149]	valid_0's auc: 0.857808
# [150]	valid_0's auc: 0.857972
# [151]	valid_0's auc: 0.858027
# [152]	valid_0's auc: 0.858283
# [153]	valid_0's auc: 0.858483
# [154]	valid_0's auc: 0.858719
# [155]	valid_0's auc: 0.858853
# [156]	valid_0's auc: 0.85897
# [157]	valid_0's auc: 0.859176
# [158]	valid_0's auc: 0.85932
# [159]	valid_0's auc: 0.859572
# [160]	valid_0's auc: 0.859805
# [161]	valid_0's auc: 0.860029
# [162]	valid_0's auc: 0.860225
# [163]	valid_0's auc: 0.860473
# [164]	valid_0's auc: 0.860651
# [165]	valid_0's auc: 0.860834
# [166]	valid_0's auc: 0.860878
# [167]	valid_0's auc: 0.861058
# [168]	valid_0's auc: 0.861252
# [169]	valid_0's auc: 0.86137
# [170]	valid_0's auc: 0.861622
# [171]	valid_0's auc: 0.861851
# [172]	valid_0's auc: 0.862021
# [173]	valid_0's auc: 0.862046
# [174]	valid_0's auc: 0.862183
# [175]	valid_0's auc: 0.862452
# [176]	valid_0's auc: 0.862597
# [177]	valid_0's auc: 0.862652
# [178]	valid_0's auc: 0.862881
# [179]	valid_0's auc: 0.863117
# [180]	valid_0's auc: 0.863348
# [181]	valid_0's auc: 0.863454
# [182]	valid_0's auc: 0.863665
# [183]	valid_0's auc: 0.863834
# [184]	valid_0's auc: 0.864034
# [185]	valid_0's auc: 0.864146
# [186]	valid_0's auc: 0.864294
# [187]	valid_0's auc: 0.864421
# [188]	valid_0's auc: 0.864489
# [189]	valid_0's auc: 0.864734
# [190]	valid_0's auc: 0.86482
# [191]	valid_0's auc: 0.864988
# [192]	valid_0's auc: 0.865117
# [193]	valid_0's auc: 0.865259
# [194]	valid_0's auc: 0.865415
# [195]	valid_0's auc: 0.865498
# [196]	valid_0's auc: 0.865492
# [197]	valid_0's auc: 0.865451
# [198]	valid_0's auc: 0.865657
# [199]	valid_0's auc: 0.865933
# [200]	valid_0's auc: 0.865905
# [201]	valid_0's auc: 0.866049
# [202]	valid_0's auc: 0.86607
# [203]	valid_0's auc: 0.866207
# [204]	valid_0's auc: 0.866391
# [205]	valid_0's auc: 0.86655
# [206]	valid_0's auc: 0.866632
# [207]	valid_0's auc: 0.866751
# [208]	valid_0's auc: 0.866904
# [209]	valid_0's auc: 0.867052
# [210]	valid_0's auc: 0.867151
# [211]	valid_0's auc: 0.867358
# [212]	valid_0's auc: 0.867459
# [213]	valid_0's auc: 0.867584
# [214]	valid_0's auc: 0.867666
# [215]	valid_0's auc: 0.867873
# [216]	valid_0's auc: 0.867986
# [217]	valid_0's auc: 0.868152
# [218]	valid_0's auc: 0.868383
# [219]	valid_0's auc: 0.868472
# [220]	valid_0's auc: 0.868566
# [221]	valid_0's auc: 0.868579
# [222]	valid_0's auc: 0.868797
# [223]	valid_0's auc: 0.868879
# [224]	valid_0's auc: 0.86909
# [225]	valid_0's auc: 0.869232
# [226]	valid_0's auc: 0.86931
# [227]	valid_0's auc: 0.86945
# [228]	valid_0's auc: 0.869546
# [229]	valid_0's auc: 0.869628
# [230]	valid_0's auc: 0.869724
# [231]	valid_0's auc: 0.86985
# [232]	valid_0's auc: 0.870003
# [233]	valid_0's auc: 0.870009
# [234]	valid_0's auc: 0.870101
# [235]	valid_0's auc: 0.870227
# [236]	valid_0's auc: 0.87026
# [237]	valid_0's auc: 0.870386
# [238]	valid_0's auc: 0.870485
# [239]	valid_0's auc: 0.870584
# [240]	valid_0's auc: 0.870705
# [241]	valid_0's auc: 0.870759
# [242]	valid_0's auc: 0.870861
# [243]	valid_0's auc: 0.870978
# [244]	valid_0's auc: 0.871142
# [245]	valid_0's auc: 0.871197
# [246]	valid_0's auc: 0.871269
# [247]	valid_0's auc: 0.871427
# [248]	valid_0's auc: 0.871392
# [249]	valid_0's auc: 0.871449
# [250]	valid_0's auc: 0.871522
# [251]	valid_0's auc: 0.871694
# [252]	valid_0's auc: 0.871816
# [253]	valid_0's auc: 0.871926
# [254]	valid_0's auc: 0.871914
# [255]	valid_0's auc: 0.87197
# [256]	valid_0's auc: 0.872046
# [257]	valid_0's auc: 0.872165
# [258]	valid_0's auc: 0.872327
# [259]	valid_0's auc: 0.872408
# [260]	valid_0's auc: 0.872487
# [261]	valid_0's auc: 0.872504
# [262]	valid_0's auc: 0.872664
# [263]	valid_0's auc: 0.872603
# [264]	valid_0's auc: 0.872632
# [265]	valid_0's auc: 0.872703
# [266]	valid_0's auc: 0.872806
# [267]	valid_0's auc: 0.872869
# [268]	valid_0's auc: 0.87305
# [269]	valid_0's auc: 0.873118
# [270]	valid_0's auc: 0.873196
# [271]	valid_0's auc: 0.873355
# [272]	valid_0's auc: 0.873496
# [273]	valid_0's auc: 0.873515
# [274]	valid_0's auc: 0.87363
# [275]	valid_0's auc: 0.873717
# [276]	valid_0's auc: 0.873721
# [277]	valid_0's auc: 0.873871
# [278]	valid_0's auc: 0.873941
# [279]	valid_0's auc: 0.874034
# [280]	valid_0's auc: 0.874189
# [281]	valid_0's auc: 0.874231
# [282]	valid_0's auc: 0.874269
# [283]	valid_0's auc: 0.874373
# [284]	valid_0's auc: 0.87444
# [285]	valid_0's auc: 0.874574
# [286]	valid_0's auc: 0.874667
# [287]	valid_0's auc: 0.87473
# [288]	valid_0's auc: 0.874844
# [289]	valid_0's auc: 0.874841
# [290]	valid_0's auc: 0.875008
# [291]	valid_0's auc: 0.875101
# [292]	valid_0's auc: 0.87508
# [293]	valid_0's auc: 0.875153
# [294]	valid_0's auc: 0.87522
# [295]	valid_0's auc: 0.875271
# [296]	valid_0's auc: 0.875334
# [297]	valid_0's auc: 0.875405
# [298]	valid_0's auc: 0.875412
# [299]	valid_0's auc: 0.875558
# [300]	valid_0's auc: 0.875621
# [301]	valid_0's auc: 0.87562
# [302]	valid_0's auc: 0.875648
# [303]	valid_0's auc: 0.875701
# [304]	valid_0's auc: 0.875723
# [305]	valid_0's auc: 0.875711
# [306]	valid_0's auc: 0.875765
# [307]	valid_0's auc: 0.875842
# [308]	valid_0's auc: 0.875884
# [309]	valid_0's auc: 0.875927
# [310]	valid_0's auc: 0.875967
# [311]	valid_0's auc: 0.876102
# [312]	valid_0's auc: 0.876232
# [313]	valid_0's auc: 0.876256
# [314]	valid_0's auc: 0.876309
# [315]	valid_0's auc: 0.876364
# [316]	valid_0's auc: 0.876445
# [317]	valid_0's auc: 0.876498
# [318]	valid_0's auc: 0.876577
# [319]	valid_0's auc: 0.876589
# [320]	valid_0's auc: 0.876687
# [321]	valid_0's auc: 0.876736
# [322]	valid_0's auc: 0.876806
# [323]	valid_0's auc: 0.876849
# [324]	valid_0's auc: 0.876898
# [325]	valid_0's auc: 0.876965
# [326]	valid_0's auc: 0.877017
# [327]	valid_0's auc: 0.8771
# [328]	valid_0's auc: 0.877146
# [329]	valid_0's auc: 0.877216
# [330]	valid_0's auc: 0.877223
# [331]	valid_0's auc: 0.87729
# [332]	valid_0's auc: 0.877394
# [333]	valid_0's auc: 0.877479
# [334]	valid_0's auc: 0.877466
# [335]	valid_0's auc: 0.877574
# [336]	valid_0's auc: 0.877604
# [337]	valid_0's auc: 0.877624
# [338]	valid_0's auc: 0.87765
# [339]	valid_0's auc: 0.877678
# [340]	valid_0's auc: 0.877682
# [341]	valid_0's auc: 0.877759
# [342]	valid_0's auc: 0.877765
# [343]	valid_0's auc: 0.877811
# [344]	valid_0's auc: 0.877833
# [345]	valid_0's auc: 0.877851
# [346]	valid_0's auc: 0.877878
# [347]	valid_0's auc: 0.877926
# [348]	valid_0's auc: 0.877983
# [349]	valid_0's auc: 0.878096
# [350]	valid_0's auc: 0.878114
# [351]	valid_0's auc: 0.878139
# [352]	valid_0's auc: 0.878251
# [353]	valid_0's auc: 0.878305
# [354]	valid_0's auc: 0.878419
# [355]	valid_0's auc: 0.878478
# [356]	valid_0's auc: 0.878488
# [357]	valid_0's auc: 0.878543
# [358]	valid_0's auc: 0.878582
# [359]	valid_0's auc: 0.878632
# [360]	valid_0's auc: 0.878695
# [361]	valid_0's auc: 0.878798
# [362]	valid_0's auc: 0.878814
# [363]	valid_0's auc: 0.878869
# [364]	valid_0's auc: 0.878942
# [365]	valid_0's auc: 0.879003
# [366]	valid_0's auc: 0.879129
# [367]	valid_0's auc: 0.879121
# [368]	valid_0's auc: 0.879118
# [369]	valid_0's auc: 0.879195
# [370]	valid_0's auc: 0.87929
# [371]	valid_0's auc: 0.879282
# [372]	valid_0's auc: 0.879338
# [373]	valid_0's auc: 0.879419
# [374]	valid_0's auc: 0.879484
# [375]	valid_0's auc: 0.879528
# [376]	valid_0's auc: 0.8796
# [377]	valid_0's auc: 0.879578
# [378]	valid_0's auc: 0.879578
# [379]	valid_0's auc: 0.879659
# [380]	valid_0's auc: 0.879704
# [381]	valid_0's auc: 0.879774
# [382]	valid_0's auc: 0.879762
# [383]	valid_0's auc: 0.879842
# [384]	valid_0's auc: 0.87988
# [385]	valid_0's auc: 0.879873
# [386]	valid_0's auc: 0.879932
# [387]	valid_0's auc: 0.879921
# [388]	valid_0's auc: 0.879959
# [389]	valid_0's auc: 0.879994
# [390]	valid_0's auc: 0.880021
# [391]	valid_0's auc: 0.880062
# [392]	valid_0's auc: 0.88008
# [393]	valid_0's auc: 0.880109
# [394]	valid_0's auc: 0.880166
# [395]	valid_0's auc: 0.880142
# [396]	valid_0's auc: 0.880171
# [397]	valid_0's auc: 0.880172
# [398]	valid_0's auc: 0.880175
# [399]	valid_0's auc: 0.880206
# [400]	valid_0's auc: 0.880251
# [401]	valid_0's auc: 0.880324
# [402]	valid_0's auc: 0.880272
# [403]	valid_0's auc: 0.880353
# [404]	valid_0's auc: 0.880377
# [405]	valid_0's auc: 0.880384
# [406]	valid_0's auc: 0.880435
# [407]	valid_0's auc: 0.880467
# [408]	valid_0's auc: 0.880515
# [409]	valid_0's auc: 0.880524
# [410]	valid_0's auc: 0.880512
# [411]	valid_0's auc: 0.880528
# [412]	valid_0's auc: 0.880571
# [413]	valid_0's auc: 0.88058
# [414]	valid_0's auc: 0.880598
# [415]	valid_0's auc: 0.880598
# [416]	valid_0's auc: 0.880695
# [417]	valid_0's auc: 0.880705
# [418]	valid_0's auc: 0.880759
# [419]	valid_0's auc: 0.880709
# [420]	valid_0's auc: 0.880756
# [421]	valid_0's auc: 0.880793
# [422]	valid_0's auc: 0.880812
# [423]	valid_0's auc: 0.880867
# [424]	valid_0's auc: 0.880927
# [425]	valid_0's auc: 0.880951
# [426]	valid_0's auc: 0.881
# [427]	valid_0's auc: 0.881
# [428]	valid_0's auc: 0.881077
# [429]	valid_0's auc: 0.881123
# [430]	valid_0's auc: 0.88109
# [431]	valid_0's auc: 0.881151
# [432]	valid_0's auc: 0.881152
# [433]	valid_0's auc: 0.881186
# [434]	valid_0's auc: 0.881241
# [435]	valid_0's auc: 0.881322
# [436]	valid_0's auc: 0.881276
# [437]	valid_0's auc: 0.88129
# [438]	valid_0's auc: 0.881312
# [439]	valid_0's auc: 0.881318
# [440]	valid_0's auc: 0.881349
# [441]	valid_0's auc: 0.881412
# [442]	valid_0's auc: 0.88141
# [443]	valid_0's auc: 0.881423
# [444]	valid_0's auc: 0.881496
# [445]	valid_0's auc: 0.881521
# [446]	valid_0's auc: 0.881553
# [447]	valid_0's auc: 0.881599
# [448]	valid_0's auc: 0.881646
# [449]	valid_0's auc: 0.881661
# [450]	valid_0's auc: 0.881691
# [451]	valid_0's auc: 0.881706
# [452]	valid_0's auc: 0.881733
# [453]	valid_0's auc: 0.881749
# [454]	valid_0's auc: 0.881775
# [455]	valid_0's auc: 0.881774
# [456]	valid_0's auc: 0.881782
# [457]	valid_0's auc: 0.881803
# [458]	valid_0's auc: 0.881857
# [459]	valid_0's auc: 0.881884
# [460]	valid_0's auc: 0.881921
# [461]	valid_0's auc: 0.8819
# [462]	valid_0's auc: 0.881927
# [463]	valid_0's auc: 0.881932
# [464]	valid_0's auc: 0.881968
# [465]	valid_0's auc: 0.882025
# [466]	valid_0's auc: 0.882015
# [467]	valid_0's auc: 0.882079
# [468]	valid_0's auc: 0.882088
# [469]	valid_0's auc: 0.882145
# [470]	valid_0's auc: 0.882145
# [471]	valid_0's auc: 0.882179
# [472]	valid_0's auc: 0.882195
# [473]	valid_0's auc: 0.882224
# [474]	valid_0's auc: 0.882206
# [475]	valid_0's auc: 0.882235
# [476]	valid_0's auc: 0.882307
# [477]	valid_0's auc: 0.882316
# [478]	valid_0's auc: 0.88234
# [479]	valid_0's auc: 0.882322
# [480]	valid_0's auc: 0.882372
# [481]	valid_0's auc: 0.882408
# [482]	valid_0's auc: 0.882401
# [483]	valid_0's auc: 0.882437
# [484]	valid_0's auc: 0.882448
# [485]	valid_0's auc: 0.882447
# [486]	valid_0's auc: 0.882468
# [487]	valid_0's auc: 0.882472
# [488]	valid_0's auc: 0.882521
# [489]	valid_0's auc: 0.882529
# [490]	valid_0's auc: 0.882529
# [491]	valid_0's auc: 0.882587
# [492]	valid_0's auc: 0.882625
# [493]	valid_0's auc: 0.88265
# [494]	valid_0's auc: 0.882644
# [495]	valid_0's auc: 0.88267
# [496]	valid_0's auc: 0.882683
# [497]	valid_0's auc: 0.882705
# [498]	valid_0's auc: 0.882728
# [499]	valid_0's auc: 0.88278
# [500]	valid_0's auc: 0.882812
# [501]	valid_0's auc: 0.882831
# [502]	valid_0's auc: 0.88286
# [503]	valid_0's auc: 0.882863
# [504]	valid_0's auc: 0.882896
# [505]	valid_0's auc: 0.882939
# [506]	valid_0's auc: 0.882963
# [507]	valid_0's auc: 0.882978
# [508]	valid_0's auc: 0.883001
# [509]	valid_0's auc: 0.883003
# [510]	valid_0's auc: 0.883023
# [511]	valid_0's auc: 0.883054
# [512]	valid_0's auc: 0.883063
# [513]	valid_0's auc: 0.883068
# [514]	valid_0's auc: 0.88313
# [515]	valid_0's auc: 0.883152
# [516]	valid_0's auc: 0.883123
# [517]	valid_0's auc: 0.883119
# [518]	valid_0's auc: 0.883106
# [519]	valid_0's auc: 0.883133
# [520]	valid_0's auc: 0.883137
# [521]	valid_0's auc: 0.883191
# [522]	valid_0's auc: 0.883225
# [523]	valid_0's auc: 0.883224
# [524]	valid_0's auc: 0.883237
# [525]	valid_0's auc: 0.883231
# [526]	valid_0's auc: 0.883219
# [527]	valid_0's auc: 0.883257
# [528]	valid_0's auc: 0.883292
# [529]	valid_0's auc: 0.883286
# [530]	valid_0's auc: 0.883287
# [531]	valid_0's auc: 0.883266
# [532]	valid_0's auc: 0.883308
# [533]	valid_0's auc: 0.88335
# [534]	valid_0's auc: 0.883359
# [535]	valid_0's auc: 0.883355
# [536]	valid_0's auc: 0.883391
# [537]	valid_0's auc: 0.883393
# [538]	valid_0's auc: 0.883411
# [539]	valid_0's auc: 0.88337
# [540]	valid_0's auc: 0.883358
# [541]	valid_0's auc: 0.883365
# [542]	valid_0's auc: 0.883394
# [543]	valid_0's auc: 0.883425
# [544]	valid_0's auc: 0.883411
# [545]	valid_0's auc: 0.883467
# [546]	valid_0's auc: 0.88347
# [547]	valid_0's auc: 0.883464
# [548]	valid_0's auc: 0.883503
# [549]	valid_0's auc: 0.883507
# [550]	valid_0's auc: 0.883499
# [551]	valid_0's auc: 0.88352
# [552]	valid_0's auc: 0.883509
# [553]	valid_0's auc: 0.883513
# [554]	valid_0's auc: 0.883502
# [555]	valid_0's auc: 0.88352
# [556]	valid_0's auc: 0.88348
# [557]	valid_0's auc: 0.883474
# [558]	valid_0's auc: 0.883474
# [559]	valid_0's auc: 0.883457
# [560]	valid_0's auc: 0.883447
# [561]	valid_0's auc: 0.88348
# [562]	valid_0's auc: 0.883465
# [563]	valid_0's auc: 0.883493
# [564]	valid_0's auc: 0.883501
# [565]	valid_0's auc: 0.883524
# [566]	valid_0's auc: 0.883541
# [567]	valid_0's auc: 0.883541
# [568]	valid_0's auc: 0.883564
# [569]	valid_0's auc: 0.883586
# [570]	valid_0's auc: 0.883623
# [571]	valid_0's auc: 0.883629
# [572]	valid_0's auc: 0.883658
# [573]	valid_0's auc: 0.883704
# [574]	valid_0's auc: 0.883738
# [575]	valid_0's auc: 0.883747
# [576]	valid_0's auc: 0.883735
# [577]	valid_0's auc: 0.883736
# [578]	valid_0's auc: 0.883699
# [579]	valid_0's auc: 0.88372
# [580]	valid_0's auc: 0.883757
# [581]	valid_0's auc: 0.883724
# [582]	valid_0's auc: 0.883736
# [583]	valid_0's auc: 0.883709
# [584]	valid_0's auc: 0.883677
# [585]	valid_0's auc: 0.883697
# [586]	valid_0's auc: 0.883723
# [587]	valid_0's auc: 0.883776
# [588]	valid_0's auc: 0.883808
# [589]	valid_0's auc: 0.883817
# [590]	valid_0's auc: 0.883826
# [591]	valid_0's auc: 0.883853
# [592]	valid_0's auc: 0.883859
# [593]	valid_0's auc: 0.883798
# [594]	valid_0's auc: 0.883854
# [595]	valid_0's auc: 0.883845
# [596]	valid_0's auc: 0.88385
# [597]	valid_0's auc: 0.883839
# [598]	valid_0's auc: 0.883865
# [599]	valid_0's auc: 0.883861
# [600]	valid_0's auc: 0.883872
# [601]	valid_0's auc: 0.883901
# [602]	valid_0's auc: 0.883908
# [603]	valid_0's auc: 0.883894
# [604]	valid_0's auc: 0.883903
# [605]	valid_0's auc: 0.883926
# [606]	valid_0's auc: 0.883931
# [607]	valid_0's auc: 0.883936
# [608]	valid_0's auc: 0.883961
# [609]	valid_0's auc: 0.883981
# [610]	valid_0's auc: 0.88394
# [611]	valid_0's auc: 0.883938
# [612]	valid_0's auc: 0.88397
# [613]	valid_0's auc: 0.883974
# [614]	valid_0's auc: 0.883959
# [615]	valid_0's auc: 0.883931
# [616]	valid_0's auc: 0.883946
# [617]	valid_0's auc: 0.883954
# [618]	valid_0's auc: 0.883976
# [619]	valid_0's auc: 0.883976
# [620]	valid_0's auc: 0.883978
# [621]	valid_0's auc: 0.883998
# [622]	valid_0's auc: 0.884007
# [623]	valid_0's auc: 0.883993
# [624]	valid_0's auc: 0.88401
# [625]	valid_0's auc: 0.884036
# [626]	valid_0's auc: 0.883977
# [627]	valid_0's auc: 0.883942
# [628]	valid_0's auc: 0.883995
# [629]	valid_0's auc: 0.884015
# [630]	valid_0's auc: 0.883996
# [631]	valid_0's auc: 0.884031
# [632]	valid_0's auc: 0.884086
# [633]	valid_0's auc: 0.884054
# [634]	valid_0's auc: 0.884073
# [635]	valid_0's auc: 0.884051
# [636]	valid_0's auc: 0.884072
# [637]	valid_0's auc: 0.88405
# [638]	valid_0's auc: 0.884046
# [639]	valid_0's auc: 0.884039
# [640]	valid_0's auc: 0.884009
# [641]	valid_0's auc: 0.884006
# [642]	valid_0's auc: 0.884042
# [643]	valid_0's auc: 0.884046
# [644]	valid_0's auc: 0.884031
# [645]	valid_0's auc: 0.884035
# [646]	valid_0's auc: 0.884019
# [647]	valid_0's auc: 0.884039
# [648]	valid_0's auc: 0.884042
# [649]	valid_0's auc: 0.883989
# [650]	valid_0's auc: 0.884026
# [651]	valid_0's auc: 0.884018
# [652]	valid_0's auc: 0.883988
# [653]	valid_0's auc: 0.883983
# [654]	valid_0's auc: 0.884007
# [655]	valid_0's auc: 0.884025
# [656]	valid_0's auc: 0.884033
# [657]	valid_0's auc: 0.884011
# [658]	valid_0's auc: 0.88403
# [659]	valid_0's auc: 0.884103
# [660]	valid_0's auc: 0.884114
# [661]	valid_0's auc: 0.884108
# [662]	valid_0's auc: 0.884112
# [663]	valid_0's auc: 0.884125
# [664]	valid_0's auc: 0.884109
# [665]	valid_0's auc: 0.884051
# [666]	valid_0's auc: 0.884046
# [667]	valid_0's auc: 0.884054
# [668]	valid_0's auc: 0.884059
# [669]	valid_0's auc: 0.884032
# [670]	valid_0's auc: 0.884048
# [671]	valid_0's auc: 0.884036
# [672]	valid_0's auc: 0.884033
# [673]	valid_0's auc: 0.884013
# [674]	valid_0's auc: 0.884005
# [675]	valid_0's auc: 0.884008
# [676]	valid_0's auc: 0.883981
# [677]	valid_0's auc: 0.884009
# [678]	valid_0's auc: 0.884023
# [679]	valid_0's auc: 0.883998
# [680]	valid_0's auc: 0.88399
# [681]	valid_0's auc: 0.883984
# [682]	valid_0's auc: 0.883991
# [683]	valid_0's auc: 0.883997
# [684]	valid_0's auc: 0.883956
# [685]	valid_0's auc: 0.883954
# [686]	valid_0's auc: 0.883952
# [687]	valid_0's auc: 0.883942
# [688]	valid_0's auc: 0.883946
# [689]	valid_0's auc: 0.883932
# [690]	valid_0's auc: 0.883957
# [691]	valid_0's auc: 0.88395
# [692]	valid_0's auc: 0.883944
# [693]	valid_0's auc: 0.883971
# [694]	valid_0's auc: 0.883981
# [695]	valid_0's auc: 0.883995
# [696]	valid_0's auc: 0.884018
# [697]	valid_0's auc: 0.884018
# [698]	valid_0's auc: 0.884024
# [699]	valid_0's auc: 0.884011
# [700]	valid_0's auc: 0.884003
# [701]	valid_0's auc: 0.883958
# [702]	valid_0's auc: 0.883963
# [703]	valid_0's auc: 0.883982
# [704]	valid_0's auc: 0.883979
# [705]	valid_0's auc: 0.883995
# [706]	valid_0's auc: 0.883995
# [707]	valid_0's auc: 0.883982
# [708]	valid_0's auc: 0.883999
# [709]	valid_0's auc: 0.884006
# [710]	valid_0's auc: 0.884035
# [711]	valid_0's auc: 0.884014
# [712]	valid_0's auc: 0.88401
# [713]	valid_0's auc: 0.883993
# [714]	valid_0's auc: 0.883999
# [715]	valid_0's auc: 0.884011
# [716]	valid_0's auc: 0.884003
# [717]	valid_0's auc: 0.884029
# [718]	valid_0's auc: 0.883998
# [719]	valid_0's auc: 0.884023
# [720]	valid_0's auc: 0.884051
# [721]	valid_0's auc: 0.88404
# [722]	valid_0's auc: 0.884076
# [723]	valid_0's auc: 0.884115
# [724]	valid_0's auc: 0.884162
# [725]	valid_0's auc: 0.884151
# [726]	valid_0's auc: 0.884199
# [727]	valid_0's auc: 0.884206
# [728]	valid_0's auc: 0.884192
# [729]	valid_0's auc: 0.884175
# [730]	valid_0's auc: 0.884193
# [731]	valid_0's auc: 0.884219
# [732]	valid_0's auc: 0.884247
# [733]	valid_0's auc: 0.884259
# [734]	valid_0's auc: 0.884254
# [735]	valid_0's auc: 0.884235
# [736]	valid_0's auc: 0.884281
# [737]	valid_0's auc: 0.884266
# [738]	valid_0's auc: 0.884291
# [739]	valid_0's auc: 0.88427
# [740]	valid_0's auc: 0.884264
# [741]	valid_0's auc: 0.884278
# [742]	valid_0's auc: 0.884263
# [743]	valid_0's auc: 0.884268
# [744]	valid_0's auc: 0.88426
# [745]	valid_0's auc: 0.884242
# [746]	valid_0's auc: 0.884223
# [747]	valid_0's auc: 0.884174
# [748]	valid_0's auc: 0.884171
# [749]	valid_0's auc: 0.884185
# [750]	valid_0's auc: 0.884168
# [751]	valid_0's auc: 0.884166
# [752]	valid_0's auc: 0.88415
# [753]	valid_0's auc: 0.884113
# [754]	valid_0's auc: 0.884119
# [755]	valid_0's auc: 0.884115
# [756]	valid_0's auc: 0.884114
# [757]	valid_0's auc: 0.88412
# [758]	valid_0's auc: 0.884119
# [759]	valid_0's auc: 0.884104
# [760]	valid_0's auc: 0.884104
# [761]	valid_0's auc: 0.884101
# [762]	valid_0's auc: 0.88408
# [763]	valid_0's auc: 0.88407
# [764]	valid_0's auc: 0.884061
# [765]	valid_0's auc: 0.884032
# [766]	valid_0's auc: 0.884021
# [767]	valid_0's auc: 0.884002
# [768]	valid_0's auc: 0.883963
# [769]	valid_0's auc: 0.883966
# [770]	valid_0's auc: 0.883963
# [771]	valid_0's auc: 0.88398
# [772]	valid_0's auc: 0.883981
# [773]	valid_0's auc: 0.883972
# [774]	valid_0's auc: 0.883947
# [775]	valid_0's auc: 0.883914
# [776]	valid_0's auc: 0.883883
# [777]	valid_0's auc: 0.883922
# [778]	valid_0's auc: 0.883918
# [779]	valid_0's auc: 0.883913
# [780]	valid_0's auc: 0.883897
# [781]	valid_0's auc: 0.883872
# [782]	valid_0's auc: 0.883875
# [783]	valid_0's auc: 0.883882
# [784]	valid_0's auc: 0.883849
# [785]	valid_0's auc: 0.883859
# [786]	valid_0's auc: 0.883838
# [787]	valid_0's auc: 0.883846
# [788]	valid_0's auc: 0.883862
# [789]	valid_0's auc: 0.883912
# [790]	valid_0's auc: 0.883908
# [791]	valid_0's auc: 0.883899
# [792]	valid_0's auc: 0.883864
# [793]	valid_0's auc: 0.883867
# [794]	valid_0's auc: 0.883866
# [795]	valid_0's auc: 0.883866
# [796]	valid_0's auc: 0.883879
# [797]	valid_0's auc: 0.883866
# [798]	valid_0's auc: 0.883871
# [799]	valid_0's auc: 0.883855
# [800]	valid_0's auc: 0.883869
# [801]	valid_0's auc: 0.883867
# [802]	valid_0's auc: 0.883846
# [803]	valid_0's auc: 0.883859
# [804]	valid_0's auc: 0.883893
# [805]	valid_0's auc: 0.883887
# [806]	valid_0's auc: 0.883855
# [807]	valid_0's auc: 0.883821
# [808]	valid_0's auc: 0.883847
# [809]	valid_0's auc: 0.883865
# [810]	valid_0's auc: 0.883849
# [811]	valid_0's auc: 0.883872
# [812]	valid_0's auc: 0.883899
# [813]	valid_0's auc: 0.883873
# [814]	valid_0's auc: 0.883894
# [815]	valid_0's auc: 0.883928
# [816]	valid_0's auc: 0.883895
# [817]	valid_0's auc: 0.883893
# [818]	valid_0's auc: 0.883904
# [819]	valid_0's auc: 0.883907
# [820]	valid_0's auc: 0.883904
# [821]	valid_0's auc: 0.883908
# [822]	valid_0's auc: 0.883928
# [823]	valid_0's auc: 0.883946
# [824]	valid_0's auc: 0.883952
# [825]	valid_0's auc: 0.883956
# [826]	valid_0's auc: 0.883976
# [827]	valid_0's auc: 0.883987
# [828]	valid_0's auc: 0.883932
# [829]	valid_0's auc: 0.883954
# [830]	valid_0's auc: 0.883946
# [831]	valid_0's auc: 0.883976
# [832]	valid_0's auc: 0.883988
# [833]	valid_0's auc: 0.883993
# [834]	valid_0's auc: 0.883982
# [835]	valid_0's auc: 0.883995
# [836]	valid_0's auc: 0.883971
# [837]	valid_0's auc: 0.883958
# [838]	valid_0's auc: 0.883952
# Early stopping, best iteration is:
# [738]	valid_0's auc: 0.884291
# Eğitim bitti...
# En iyi sonucu veren iterasyon:  738
# Eğri altı alan değeri: 0.8842914970233466
# İsabetlilik değeri: 0.80075
